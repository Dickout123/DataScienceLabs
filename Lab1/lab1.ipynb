# %% [markdown]
# # Аналіз даних для Data Science Labs
#
# Цей Jupyter Notebook створено в рамках лабораторної роботи для:
# 1. Демонстрації налаштування середовища Python/NumPy.
# 2. Виконання базових операцій з даними.
# 3. Збереження історії роботи та синхронізації з репозиторієм GitHub.

# %%
# Завдання: запитати ім'я та вивести привітання
user_name = input("Будь ласка, введіть своє ім'я: ")
print(f"Hello, {user_name}!")

# %%
import numpy as np

# 1. Створення масиву з 10 випадкових чисел (від 0 до 1)
# np.random.rand(10) генерує 10 випадкових чисел.
random_array = np.random.rand(10)

print("Згенерований випадковий масив:")
print(random_array)

# 2. Обчислення середнього значення
mean_value = np.mean(random_array)

print(f"\nСереднє значення масиву: {mean_value}")
